# %%
print("Hello World")
# Out:
# Hello World

# %%
name=input("Enter your name")
print(name)
# Out:
# Ahmed

# %%
abc=14+5j
print(type(abc))
# Out:
# <class 'complex'>

# %%
string_paragraph ='Machine learning is a subfield of artificial intelligence that gives computers the ability to learn without explicitly being programmed.'
print('Type :',type(string_paragraph))
# Out:
# Type : <class 'str'>

# %%
t = 'Hello World!'
print (t) # Prints complete string
print (t[0]) # Prints first character of the string
print(t[2:5]) # Prints characters starting from 3rd to 5th
print (t[2:]) # Prints string starting from 3rd character
print (t* 2)# Prints string two times
print (t + 'TEST') # Prints concatenated string
# Out:
# Hello World!
# H
# llo
# llo World!
# Hello World!Hello World!
# Hello World!TEST

# %%
list=['Phy','Chem','Math',3,5,1.23,1+3j]
print(list[1:5])
list[2]=12
print(list[2])
# Out:
# ['Chem', 'Math', 3, 5]
# 12

# %%
dict={}
dict['Me']="Affan"
dict[3]="Ahmed"
print(dict['Me']+' '+dict[3])
# Out:
# Affan Ahmed

# %%
amount=int(input("Enter Amount:"))
if amount>=50000:
 print("Good")
else:
 print("Not Good")
# Out:
# Not Good
