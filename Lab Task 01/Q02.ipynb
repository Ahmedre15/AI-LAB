# %%
Name=input("Enter String: ")
print(Name[0])
print(Name[len(Name)-1])
print(len(Name))
print(Name*2)
count=0
for var in Name:
 if var!=' ':
  print(var)
  count+=1
print("Counter= ",count)
# Out:
# M
# s
# 10
# My name isMy name is
# M
# y
# n
# a
# m
# e
# i
# s
# Counter=  8
