# %%
def discount(amount):
    if amount<1000:
        total=amount-amount*0.05
        return total
    elif amount<5000:
        total=amount-amount*0.1
        return total
    else:
        total=amount-amount*0.15
        return total
    
total=discount(3600)
print("Payable Amount: ",total)
# Out:
# Payable Amount:  3240.0
