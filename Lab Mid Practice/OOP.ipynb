# %%
class student:
    x=5
    def __init__(self,x):
        self.x=x

    def print(self,x):
        print(f"Value of x:{self.x}")


class teacher(student):
     print(self,x):
   

s1=student(6)
print(s1.x)
s1.print(s1.x)
# Out:
# 6
# Value of x:6

# %%
class student:
    def __init__(self,name):
        self.name=name
        self.__grade=0
    def setgrade(self,grade):
        self.__grade=grade
    def getgrade(self):
        return self.__grade
